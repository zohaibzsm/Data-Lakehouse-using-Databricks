# %% [markdown]
# ### Load Silver Table

# %%
df = spark.table("salesdatalakehouse.silver.erp_loc_a101")

# %% [markdown]
# ### Invalid char check

# %%
# %sql
SELECT customer_id
FROM salesdatalakehouse.silver.erp_loc_a101
WHERE customer_id NOT IN (
SELECT customer_key
FROM salesdatalakehouse.silver.crm_cust_info)

# %% [markdown]
# ## Normalization

# %%
df.select("country").distinct().show()
